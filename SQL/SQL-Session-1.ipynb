# %% [markdown]
# # Session 1 SQL in Python
#
# were using SQL lite that makes a database server but in ou5 local memory (inn the codespace)
#
#
# We first had to instal sqlalchemy

# %%
from sqlalchemy import (create_engine,
                        inspect,
                        text,
                        select,
                        MetaData,
                        Table,
                        and_,
                        or_,
                        desc,
                        asc,
                        func,)

# %%
# How to connect to any SQL database 

# dialect+driver:////username:password@host:port/database
 
# "postgresql+psycopg2://will1:willspassword@postgresql.uk.amazonaws:8000/childrens_services"



chinook_engine = create_engine("sqlite+pysqlite:////workspaces/python-learning-repository/SQL/chinook.db")
# four / asv it is in or directory

# %%
# lets do a quety to find out the table nmes 

inspection = inspect(chinook_engine)

inspection.get_table_names()
# Out:
# ['albums',
#  'artists',
#  'customers',
#  'employees',
#  'genres',
#  'invoice_items',
#  'invoices',
#  'media_types',
#  'playlist_track',
#  'playlists',
#  'tracks']

# %% [markdown]
# ## Connevct to gravity database

# %%
gravity_engine = create_engine("sqlite+pysqlite:////workspaces/python-learning-repository/SQL/gravity.db")

inspection = inspect(gravity_engine)
inspection.get_table_names()
# Out:
# ['address',
#  'address_status',
#  'author',
#  'book',
#  'book_author',
#  'book_language',
#  'country',
#  'cust_order',
#  'customer',
#  'customer_address',
#  'order_history',
#  'order_line',
#  'order_status',
#  'publisher',
#  'shipping_method']

# %% [markdown]
# This is a series of different tables that wouldnt be loaded easily into one database in  python

# %%
# looking at individual tables 

# lets get data out of the database as a table 

chinook_metadata = MetaData()

tracks = Table('tracks', chinook_metadata, autoload_with=chinook_engine)
# this now contains the meta data for teh tracst table 

repr(tracks) # similar to the info() function
# Out:
# "Table('tracks', MetaData(), Column('TrackId', INTEGER(), table=<tracks>, primary_key=True, nullable=False), Column('Name', NVARCHAR(length=200), table=<tracks>, nullable=False), Column('AlbumId', INTEGER(), ForeignKey('albums.AlbumId'), table=<tracks>), Column('MediaTypeId', INTEGER(), ForeignKey('media_types.MediaTypeId'), table=<tracks>, nullable=False), Column('GenreId', INTEGER(), ForeignKey('genres.GenreId'), table=<tracks>), Column('Composer', NVARCHAR(length=220), table=<tracks>), Column('Milliseconds', INTEGER(), table=<tracks>, nullable=False), Column('Bytes', INTEGER(), table=<tracks>), Column('UnitPrice', NUMERIC(precision=10, scale=2), table=<tracks>, nullable=False), schema=None)"

# %%
gravity_metadata = MetaData()

books = Table('book', gravity_metadata, autoload_with=gravity_engine)
# this now contains the meta data for teh tracst table 

repr(books) # similar to the info() function
# Out:
# "Table('book', MetaData(), Column('book_id', INTEGER(), table=<book>, primary_key=True), Column('title', TEXT(), table=<book>), Column('isbn13', TEXT(), table=<book>), Column('language_id', INTEGER(), ForeignKey('book_language.language_id'), table=<book>), Column('num_pages', INTEGER(), table=<book>), Column('publication_date', DATE(), table=<book>), Column('publisher_id', INTEGER(), ForeignKey('publisher.publisher_id'), table=<book>), schema=None)"

# %% [markdown]
# # Lets query the data
#
#
# A with function only holds during the with

# %%
with chinook_engine.connect() as con:
    stmt = "SELECT * FROM tracks"
    result_proxy = con.execute(text(stmt))
    results = result_proxy.fetchall()

first_row = results[0]
first_row


import pandas as pd 
df = pd.DataFrame(results)
df
# Out:
#       TrackId                                               Name  AlbumId  \
# 0           1            For Those About To Rock (We Salute You)        1
# 1           2                                  Balls to the Wall        2
# 2           3                                    Fast As a Shark        3
# 3           4                                  Restless and Wild        3
# 4           5                               Princess of the Dawn        3
# ...       ...                                                ...      ...
# 3498     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...      343
# 3499     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...      344
# 3500     3501               L'orfeo, Act 3, Sinfonia (Orchestra)      345
# 3501     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...      346
# 3502     3503                                      Koyaanisqatsi      347
#
#       MediaTypeId  GenreId                                           Composer  \
# ...

# %%
with gravity_engine.connect() as con:
    stmt = "SELECT * FROM book"
    result_proxy = con.execute(text(stmt))
    results = result_proxy.fetchmany(size=20)

df2 = pd.DataFrame(results)
df2
# Out:
#     book_id                                              title        isbn13  \
# 0         1        The World's First Love: Mary  Mother of God    8987059752
# 1         2                                     The Illuminati   20049130001
# 2         3                                 The Servant Leader   23755004321
# 3         4  What Life Was Like in the Jewel in the Crown: ...   34406054602
# 4         5  Cliffs Notes on Aristophanes' Lysistrata  The ...   49086007763
# 5         6  Life Is a Dream and Other Spanish Classics (Er...   73999140774
# 6         7                  William Goldman: Four Screenplays   73999254907
# 7         8              The Season: A Candid Look at Broadway   73999768442
# 8         9             The Beatles Complete - Updated Edition   73999960822
# 9        10               Working Effectively with Legacy Code   76092025986
# 10       11  The Complete Anne of Green Gables Boxed Set (A...   76783609419
# ...

# %%
# lets write the same thing in python not sql 

with chinook_engine.connect() as con:
    stmt = select(tracks)
    result_proxy = con.execute(stmt)
    results = result_proxy.fetchmany(10)

tracks_df = pd.DataFrame(results)
tracks_df
# Out:
#    TrackId                                     Name  AlbumId  MediaTypeId  \
# 0        1  For Those About To Rock (We Salute You)        1            1
# 1        2                        Balls to the Wall        2            2
# 2        3                          Fast As a Shark        3            2
# 3        4                        Restless and Wild        3            2
# 4        5                     Princess of the Dawn        3            2
# 5        6                    Put The Finger On You        1            1
# 6        7                          Let's Get It Up        1            1
# 7        8                         Inject The Venom        1            1
# 8        9                               Snowballed        1            1
# 9       10                               Evil Walks        1            1
#
#    GenreId                                           Composer  Milliseconds  \
# 0        1          Angus Young, Malcolm Young, Brian Johnson        343719
# ...

# %% [markdown]
# teh only diffrenec realsiticly between this and teh previous loops is that we ran it using python commands rather than the SQL funstion, which removed the need for some additional functions

# %%
with gravity_engine.connect() as con:
    stmt = select(books)
    result_proxy = con.execute(stmt)
    results = result_proxy.fetchmany(10)
    books_df = pd.DataFrame(results)

books_df
# Out:
#    book_id                                              title       isbn13  \
# 0        1        The World's First Love: Mary  Mother of God   8987059752
# 1        2                                     The Illuminati  20049130001
# 2        3                                 The Servant Leader  23755004321
# 3        4  What Life Was Like in the Jewel in the Crown: ...  34406054602
# 4        5  Cliffs Notes on Aristophanes' Lysistrata  The ...  49086007763
# 5        6  Life Is a Dream and Other Spanish Classics (Er...  73999140774
# 6        7                  William Goldman: Four Screenplays  73999254907
# 7        8              The Season: A Candid Look at Broadway  73999768442
# 8        9             The Beatles Complete - Updated Edition  73999960822
# 9       10               Working Effectively with Legacy Code  76092025986
#
#    language_id  num_pages publication_date  publisher_id
# 0            2        276       1996-09-01          1010
# ...

# %%
# and_ or_ 

with chinook_engine.connect() as con:
    stmt = select(tracks).where(or_(tracks.columns.AlbumId == 1,
                                    tracks.columns.AlbumId == 2))
    result_proxy = con.execute(stmt)
    results = result_proxy.fetchmany(10)

df = pd.DataFrame(results)
df
# Out:
#    TrackId                                     Name  AlbumId  MediaTypeId  \
# 0        1  For Those About To Rock (We Salute You)        1            1
# 1        6                    Put The Finger On You        1            1
# 2        7                          Let's Get It Up        1            1
# 3        8                         Inject The Venom        1            1
# 4        9                               Snowballed        1            1
# 5       10                               Evil Walks        1            1
# 6       11                                   C.O.D.        1            1
# 7       12                       Breaking The Rules        1            1
# 8       13                 Night Of The Long Knives        1            1
# 9       14                               Spellbound        1            1
#
#    GenreId                                   Composer  Milliseconds     Bytes  \
# ...

# %%
# Find rows for the books: 'Working Effectively with Legacy Code' and "The Basic Works of Aristotle"
# print the book_id of both

with gravity_engine.connect() as con:
    # Selecting all tracks where the album ID column is 1 or 2 (Third column)
    stmt = select(books).where(or_(books.columns.title == 'Working Effectively with Legacy Code', 
                                      books.columns.title == "The Basic Works of Aristotle")) 
    result_proxy = con.execute(stmt)
    results = result_proxy.fetchmany(size=20) 

print(results[0].book_id)
print(results[1].book_id)
# Out:
# 10
# 3216

# %%
# Ordering results, use order_by(desc()),  (descending), order by multiple by passing multiple columns to sort by

# function
with engine.connect() as con:
    stmt = select(tracks).order_by(desc(tracks.columns.Composer))
    result_proxy = con.execute(stmt)
    results = result_proxy.fetchmany(size=10) 

df = pd.DataFrame(results)
df
# Out:
#    TrackId                   Name  AlbumId  MediaTypeId  GenreId  \
# 0      817             Lick It Up       66            1        1
# 1      819        Talk About Love       66            1        1
# 2      820           Time To Kill       66            1        1
# 3      821         Ramshackle Man       66            1        1
# 4      822    A Twist In The Tail       66            1        1
# 5      824              Solitaire       66            1        1
# 6      825         One Man's Meat       66            1        1
# 7     1055  Loves Been Good To Me       83            1       12
# 8     1041    For Once In My Life       83            1       12
# 9     1052    The Lady Is A Tramp       83            1       12
#
#                        Composer  Milliseconds     Bytes UnitPrice
# 0                  roger glover        240274   7792604      0.99
# 1                  roger glover        247823   8072171      0.99
# ...

# %%
# object oriented, and ordeing by multiple columns, one desc, one asc
with engine.connect() as con:
    stmt = select(tracks).order_by(tracks.columns.Composer.desc(), tracks.columns.Name.asc())
    result_proxy = con.execute(stmt)
    results = result_proxy.fetchmany(size=10) 

df = pd.DataFrame(results)
df
# Out:
#    TrackId                   Name  AlbumId  MediaTypeId  GenreId  \
# 0      822    A Twist In The Tail       66            1        1
# 1      817             Lick It Up       66            1        1
# 2      825         One Man's Meat       66            1        1
# 3      821         Ramshackle Man       66            1        1
# 4      824              Solitaire       66            1        1
# 5      819        Talk About Love       66            1        1
# 6      820           Time To Kill       66            1        1
# 7     1055  Loves Been Good To Me       83            1       12
# 8     1041    For Once In My Life       83            1       12
# 9     1052    The Lady Is A Tramp       83            1       12
#
#                        Composer  Milliseconds     Bytes UnitPrice
# 0                  roger glover        257462   8413103      0.99
# 1                  roger glover        240274   7792604      0.99
# ...

# %%
with gravity_engine.connect() as con:
    stmt = select(books).order_by(books.columns.num_pages.desc())
    result_proxy = con.execute(stmt)
    results = result_proxy.fetchmany(10)

df = pd.DataFrame(results)
df
# Out:
#    book_id                                              title         isbn13  \
# 0     3564     The Complete Aubrey/Maturin Novels (5 Volumes)  9780393060119
# 1     3749                               The Second World War  9780395416853
# 2     6460             Remembrance of Things Past (Boxed Set)  9780701125592
# 3     4138       Harry Potter Collection (Harry Potter  #1-6)  9780439827607
# 4     8297                           Summa Theologica  5 Vols  9780870610639
# 5      796         Harrison's Principles of Internal Medicine  9780071391405
# 6     4121  Harry Potter Boxed Set  Books 1-5 (Harry Potte...  9780439682589
# 7     7960  The Sword of Truth  Boxed Set I: Wizard's Firs...  9780812575606
# 8     5713             The J.R.R. Tolkien Companion and Guide  9780618391134
# 9     2212                                   Study Bible: NIV  9780310929550
#
#    language_id  num_pages publication_date  publisher_id
# 0            1       6576       2004-10-17          2143
# ...

# %%
with chinook_engine.connect() as con:
    stmt = select(func.sum(tracks.columns.Milliseconds))
    results = con.execute(stmt).scalar()

results
# Out:
# 1378778040

# %%
# find the total number of pages of all books in gravity

with gravity_engine.connect() as con:
    stmt = select(func.sum(books.columns.num_pages))
    results = con.execute(stmt).scalar() 
print(results)
