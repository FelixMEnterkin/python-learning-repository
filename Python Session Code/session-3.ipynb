# %% [markdown]
# # Session 3
# This is the follow along with session 3

# %%
import pandas as pd

# %% [markdown]
# Pandas allows us to work with tabula data the name itself comes from pannel data.  As a standard it is loaded in using teh call pd to make code more compact
# later we will use plotly.express to plot function

# %%
filename = r"https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/1980%202023%20average%20house%20prices.csv"

# for an csv file 
df = pd.read_csv(filename)

# for an excel file 
#df = pd.read_excel(filename, sheet_name=['sheet 1', 'sheet 2'])

# when loading an excel file this way teh defult behaviour is to load in the first sheet, otherwise we need to specify. 
## to illustrate: 

#df_l = read_excel(filepath, sheet_name=["sheet name 1", "Sheet name 2"] )
# this will read in each sheet as a dataframe and store it in a dictionary 
dfs = {
    "df1": "Sheet 1",
    "df2": "sheet 2"
}

# using excel files it is easier to use teh specific excel manipulation packedge openpyxl
# import openpyxl

# %% [markdown]
# Anoconda has a really nice viewer for charts and data - Will would recomend it for using python. This is also the editer that nearly all La's use to interact with python.

# %%
## Lets get the informatio from this dataframe
df.info()
# This allows us to look at the different columns, their names and what type of data they have 

# We can also look at the top and bottom of dataframes with head or tail 
df.head() # top row
df.tail() # bottom row
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523 entries, 0 to 522
# Data columns (total 6 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Name                                            523 non-null    object
#  1   Period                                          523 non-null    object
#  2   House price index All property types            523 non-null    float64
#  3   Average price All property types                523 non-null    int64
#  4   Percentage change (monthly) All property types  523 non-null    float64
#  5   Percentage change (yearly) All property types   523 non-null    float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 24.6+ KB
#                Name   Period  House price index All property types  \
# 518  United Kingdom  2023-03                                 148.2
# 519  United Kingdom  2023-04                                 148.9
# 520  United Kingdom  2023-05                                 149.5
# 521  United Kingdom  2023-06                                 151.2
# 522  United Kingdom  2023-07                                 152.0
#
#      Average price All property types  \
# 518                            282548
# 519                            283871
# 520                            285053
# 521                            288281
# 522                            289824
#
#      Percentage change (monthly) All property types  \
# 518                                            -1.0
# 519                                             0.5
# 520                                             0.4
# 521                                             1.1
# 522                                             0.5
#
#      Percentage change (yearly) All property types
# 518                                            3.2
# 519                                            2.5
# 520                                            1.6
# 521                                            1.9
# 522                                            0.6

# %%
# to raed from local files you need to import your operating system using the lines:
import os

# this module allows us to interact wioth files folder and directories

# %%
# Lets load new data 
childid = pd.read_csv("/workspaces/python-learning-repository/example _data/ChildIdentifiers.csv")

childid.info()
childid.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               332 non-null    int64
#  1   LAchildID                332 non-null    object
#  2   UPN                      332 non-null    object
#  3   FormerUPN                0 non-null      float64
#  4   UPNunknown               0 non-null      float64
#  5   PersonBirthDate          332 non-null    object
#  6   ExpectedPersonBirthDate  7 non-null      object
#  7   GenderCurrent            332 non-null    int64
#  8   PersonDeathDate          21 non-null     object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 23.5+ KB
#    Unnamed: 0        LAchildID            UPN  FormerUPN  UPNunknown  \
# 0           0  RND000215205141  A850728973744        NaN         NaN
# 1           1  RND000824303014  A141396438491        NaN         NaN
# 2           2  RND000750143123  A929946861554        NaN         NaN
# 3           3  RND000909164501  A612330267292        NaN         NaN
# 4           4  RND000382171815  A604459366806        NaN         NaN
#
#   PersonBirthDate ExpectedPersonBirthDate  GenderCurrent PersonDeathDate
# 0      06/12/2019                     NaN              1             NaN
# 1      27/04/2011                     NaN              9             NaN
# 2      06/06/2017              06/12/2019              1             NaN
# 3      03/10/2014                     NaN              0             NaN
# 4      25/09/2019                     NaN              2             NaN

# %%
# we need to convert to datetime 
# This can be done through pandas using their to_datetime function

df["Period"] = pd.to_datetime(df["Period"], format="%Y-%m")
# Note. Here we specify the format of the date originally is in. We would need another funtion to convert a date

# %%
# Letsd repeat thi with the child identifiers dataset

filepath = r"https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/ChildIdentifiers.csv"
child_identifiers = pd.read_csv(filepath)
child_identifiers

# converting the dates into datetime objects 
child_identifiers['ExpectedPersonBirthDate'] = pd.to_datetime(child_identifiers['ExpectedPersonBirthDate'], format="%Y-%m-%d")
child_identifiers.info()

# lets handle the error 
child_identifiers['PersonBirthDate'] = pd.to_datetime(child_identifiers['PersonBirthDate'], format="%Y-%m-%d", errors="ignore")
child_identifiers['PersonDeathDate'] = pd.to_datetime(child_identifiers['PersonDeathDate'], format="%Y-%m-%d", errors="coerce")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               332 non-null    int64
#  1   LAchildID                332 non-null    object
#  2   UPN                      332 non-null    object
#  3   FormerUPN                0 non-null      float64
#  4   UPNunknown               0 non-null      float64
#  5   PersonBirthDate          332 non-null    object
#  6   ExpectedPersonBirthDate  7 non-null      datetime64[ns]
#  7   GenderCurrent            332 non-null    int64
#  8   PersonDeathDate          21 non-null     object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 23.5+ KB
# /tmp/ipykernel_26762/3335976524.py:10: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   child_identifiers['PersonBirthDate'] = pd.to_datetime(child_identifiers['PersonBirthDate'], format="%Y-%m-%d", errors="ignore")

# %% [markdown]
# In datetimes objects all of the characters start with a % sign, e.g., %m is month like 09. This is because Python uses strftime to specify the date formats: https://strftime.org/. In this case as the dates in the original data are yyyy-mm-dd then we can use the strftime '%Y-%m-%d' to denote this to pandas.

# %%
# lets calculate the age 

# We can do this by subtracting the date of birth from todays date, or in this case a reference date
child_identifiers["Age"] = pd.to_datetime('01/04/24', dayfirst=True) - child_identifiers["PersonBirthDate"]
child_identifiers.info()

# here the age has printed at a Timedelta that counts teh total number of days.  We will need to correct in order to turn this into an integer reflecting years 

# we can divide it by the number of days in a year to get the years using pandas `Timedelta` function
child_identifiers["Age"] = child_identifiers["Age"] / pd.Timedelta(365.25, 'd')

# but we do not want a decimal number (float) so we need to round to the year. In this case for years we are rounding down and not up, but luckely the 'int' funtion will convert
# floats to intigers by rounding down:
child_identifiers["Age"] = child_identifiers["Age"].astype('int') # int will always round down 
child_identifiers

# Should we want to round normally we cound use a funtion like `round`
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               332 non-null    int64
#  1   LAchildID                332 non-null    object
#  2   UPN                      332 non-null    object
#  3   FormerUPN                0 non-null      float64
#  4   UPNunknown               0 non-null      float64
#  5   PersonBirthDate          332 non-null    datetime64[ns]
#  6   ExpectedPersonBirthDate  7 non-null      datetime64[ns]
#  7   GenderCurrent            332 non-null    int64
#  8   PersonDeathDate          20 non-null     datetime64[ns]
#  9   Age                      332 non-null    timedelta64[ns]
#  10  age                      332 non-null    timedelta64[ns]
# dtypes: datetime64[ns](3), float64(2), int64(2), object(2), timedelta64[ns](2)
# memory usage: 28.7+ KB
#      Unnamed: 0        LAchildID            UPN  FormerUPN  UPNunknown  \
# 0             0  RND000215205141  A850728973744        NaN         NaN
# 1             1  RND000824303014  A141396438491        NaN         NaN
# 2             2  RND000750143123  A929946861554        NaN         NaN
# 3             3  RND000909164501  A612330267292        NaN         NaN
# 4             4  RND000382171815  A604459366806        NaN         NaN
# ..          ...              ...            ...        ...         ...
# 327         327  RND000112711501  A465246916125        NaN         NaN
# 328         328  RND000513120794  A540014111973        NaN         NaN
# 329         329  RND000541643134  A549582689058        NaN         NaN
# 330         330  RND000404939452  A889492349196        NaN         NaN
# 331         331  RND000589802835  A877624860226        NaN         NaN
#
#     PersonBirthDate ExpectedPersonBirthDate  GenderCurrent PersonDeathDate  \
# 0        2019-12-06                     NaT              1             NaT
# 1        2011-04-27                     NaT              9             NaT
# 2        2017-06-06              2019-12-06              1             NaT
# 3        2014-10-03                     NaT              0             NaT
# 4        2019-09-25                     NaT              2             NaT
# ..              ...                     ...            ...             ...
# 327      2010-07-07                     NaT              2             NaT
# 328      2018-08-14                     NaT              2             NaT
# 329      2021-12-09                     NaT             51             NaT
# 330      2013-07-23                     NaT              2             NaT
# 331      2021-10-25                     NaT              9             NaT
#
#      Age                       age
# 0      4 1645 days 13:38:54.803234
# 1     12 4790 days 13:38:54.803234
# 2      6 2558 days 13:38:54.803234
# 3      9 3535 days 13:38:54.803234
# 4      4 1717 days 13:38:54.803234
# ..   ...                       ...
# 327   13 5084 days 13:38:54.803234
# 328    5 2124 days 13:38:54.803234
# 329    2  911 days 13:38:54.803234
# 330   10 3972 days 13:38:54.803234
# 331    2  956 days 13:38:54.803234
#
# [332 rows x 11 columns]

# %%
# quicker way although it doesnt seem to work in codespace is to use the numpy packedge:
# import numpy as np 

#child_identifiers["age"] = pd.to_datetime('today') - child_identifiers["PersonBirthDate"]
#child_identifiers["age"] = child_identifiers["age"] / np.timedelta64(1, "Y")
